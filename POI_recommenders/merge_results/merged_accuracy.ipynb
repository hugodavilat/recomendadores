# %%
def get_result(dataset, recommender):
    accs10, accs50, accs100, preds = [], [], [], []
    result = 'result/' + recommender + '_' + dataset + '_2.txt'
    with open(result) as result_file:
        for line in result_file.readlines()[1:]:
            _, _, _, _, acc10, acc50, acc100, _, pred = line.strip().split('\t')
            accs10.append(float(acc10))
            accs50.append(float(acc50))
            accs100.append(float(acc100))
            preds.append(float(pred))
    return accs10, accs50, accs100, preds

# %%
import matplotlib.pyplot as plt
import numpy as np
import scipy.stats

def plt_chart(x, y, title, x_label, y_label):
    fig, ax = plt.subplots()
    ax.scatter(x, y)
    ax.set_xlabel(x_label)
    ax.set_ylabel(y_label)
    ax.set_title(title)

def get_corr(x, y):
    # (correlation, p-value)
    pearson = scipy.stats.pearsonr(x, y)
    # SpearmanrResult(correlation, pvalue)
    spearman = scipy.stats.spearmanr(x, y)
    # KendalltauResult(correlation, pvalue)
    kendall = scipy.stats.kendalltau(x, y)
    print(f'Pearson:\n\tcorr: {round(pearson[0], 3)}\n\tp-value: {round(pearson[0], 3)}\n')
    print(f'Spearman:\n\tcorr: {round(spearman.correlation, 3)}\n\tp-value: {round(spearman.pvalue, 3)}\n')
    print(f'Kendall:\n\tcorr: {round(kendall.correlation, 3)}\n\tp-value: {round(kendall.pvalue, 3)}\n')

# %%
ds, rc = 'gow', 'lfbca'
acc10, acc50, acc100, preds = get_result(ds, rc)
plt_chart(preds, acc10, 'Dataset: Gowalla; Recommender: LFBCA', 'Predictability', 'Accuracy@10')
get_corr(preds, acc10)
# Out:
# Pearson:
# 	corr: 0.056
# 	p-value: 0.056
#
# Spearman:
# 	corr: 0.086
# 	p-value: 0.0
#
# Kendall:
# 	corr: 0.065
# 	p-value: 0.0

# %%
ds, rc = 'gow', 'lfbca'
acc10, acc50, acc100, preds = get_result(ds, rc)
plt_chart(preds, acc50, 'Dataset: Gowalla; Recommender: LFBCA', 'Predictability', 'Accuracy@50')
get_corr(preds, acc50)
# Out:
# Pearson:
# 	corr: 0.08
# 	p-value: 0.08
#
# Spearman:
# 	corr: 0.093
# 	p-value: 0.0
#
# Kendall:
# 	corr: 0.066
# 	p-value: 0.0

# %%
ds, rc = 'gow', 'lfbca'
acc10, acc50, acc100, preds = get_result(ds, rc)
plt_chart(preds, acc100, 'Dataset: Gowalla; Recommender: LFBCA', 'Predictability', 'Accuracy@100')
get_corr(preds, acc100)
# Out:
# Pearson:
# 	corr: 0.097
# 	p-value: 0.097
#
# Spearman:
# 	corr: 0.101
# 	p-value: 0.0
#
# Kendall:
# 	corr: 0.07
# 	p-value: 0.0

# %%
ds, rc = 'yelp', 'lfbca'
acc10, acc50, acc100, preds = get_result(ds, rc)
plt_chart(preds, acc10, 'Dataset: Yelp; Recommender: LFBCA', 'Predictability', 'Accuracy@10')
get_corr(preds, acc10)
# Out:
# Pearson:
# 	corr: -0.006
# 	p-value: -0.006
#
# Spearman:
# 	corr: 0.05
# 	p-value: 0.0
#
# Kendall:
# 	corr: 0.044
# 	p-value: 0.0

# %%
ds, rc = 'yelp', 'lfbca'
acc10, acc50, acc100, preds = get_result(ds, rc)
plt_chart(preds, acc50, 'Dataset: Yelp; Recommender: LFBCA', 'Predictability', 'Accuracy@50')
get_corr(preds, acc50)
# Out:
# Pearson:
# 	corr: -0.014
# 	p-value: -0.014
#
# Spearman:
# 	corr: 0.03
# 	p-value: 0.0
#
# Kendall:
# 	corr: 0.025
# 	p-value: 0.0

# %%
ds, rc = 'yelp', 'lfbca'
acc10, acc50, acc100, preds = get_result(ds, rc)
plt_chart(preds, acc100, 'Dataset: Yelp; Recommender: LFBCA', 'Predictability', 'Accuracy@100')
get_corr(preds, acc100)
# Out:
# Pearson:
# 	corr: -0.015
# 	p-value: -0.015
#
# Spearman:
# 	corr: 0.01
# 	p-value: 0.091
#
# Kendall:
# 	corr: 0.008
# 	p-value: 0.078

# %%
ds, rc = 'yelp', 'geosoca'
acc10, acc50, acc100, preds = get_result(ds, rc)
plt_chart(preds, acc10, 'Dataset: Yelp; Recommender: GeoSoCa', 'Predictability', 'Accuracy@10')
get_corr(preds, acc10)
# Out:
# Pearson:
# 	corr: 0.016
# 	p-value: 0.016
#
# Spearman:
# 	corr: 0.082
# 	p-value: 0.0
#
# Kendall:
# 	corr: 0.073
# 	p-value: 0.0

# %%
ds, rc = 'yelp', 'geosoca'
acc10, acc50, acc100, preds = get_result(ds, rc)
plt_chart(preds, acc50, 'Dataset: Yelp; Recommender: GeoSoCa', 'Predictability', 'Accuracy@50')
get_corr(preds, acc50)
# Out:
# Pearson:
# 	corr: 0.026
# 	p-value: 0.026
#
# Spearman:
# 	corr: 0.104
# 	p-value: 0.0
#
# Kendall:
# 	corr: 0.09
# 	p-value: 0.0

# %%
ds, rc = 'yelp', 'geosoca'
acc10, acc50, acc100, preds = get_result(ds, rc)
plt_chart(preds, acc100, 'Dataset: Yelp; Recommender: GeoSoCa', 'Predictability', 'Accuracy@100')
get_corr(preds, acc100)
# Out:
# Pearson:
# 	corr: 0.035
# 	p-value: 0.035
#
# Spearman:
# 	corr: 0.107
# 	p-value: 0.0
#
# Kendall:
# 	corr: 0.091
# 	p-value: 0.0

# %%
ds, rc = 'yelp', 'lore'
acc10, acc50, acc100, preds = get_result(ds, rc)
plt_chart(preds, acc10, 'Dataset: Yelp; Recommender: LORE', 'Predictability', 'Accuracy@10')
get_corr(preds, acc10)
# Out:
# Pearson:
# 	corr: 0.01
# 	p-value: 0.01
#
# Spearman:
# 	corr: 0.077
# 	p-value: 0.0
#
# Kendall:
# 	corr: 0.068
# 	p-value: 0.0

# %%
ds, rc = 'yelp', 'lore'
acc10, acc50, acc100, preds = get_result(ds, rc)
plt_chart(preds, acc50, 'Dataset: Yelp; Recommender: LORE', 'Predictability', 'Accuracy@50')
get_corr(preds, acc50)
# Out:
# Pearson:
# 	corr: 0.016
# 	p-value: 0.016
#
# Spearman:
# 	corr: 0.1
# 	p-value: 0.0
#
# Kendall:
# 	corr: 0.086
# 	p-value: 0.0

# %%
ds, rc = 'yelp', 'lore'
acc10, acc50, acc100, preds = get_result(ds, rc)
plt_chart(preds, acc100, 'Dataset: Yelp; Recommender: LORE', 'Predictability', 'Accuracy@100')
get_corr(preds, acc100)
# Out:
# Pearson:
# 	corr: 0.033
# 	p-value: 0.033
#
# Spearman:
# 	corr: 0.114
# 	p-value: 0.0
#
# Kendall:
# 	corr: 0.097
# 	p-value: 0.0

# %%
ds, rc = 'gow', 'lore'
acc10, acc50, acc100, preds = get_result(ds, rc)
plt_chart(preds, acc10, 'Dataset: Gowalla; Recommender: LORE', 'Predictability', 'Accuracy@10')
get_corr(preds, acc10)
# Out:
# Pearson:
# 	corr: 0.114
# 	p-value: 0.114
#
# Spearman:
# 	corr: 0.145
# 	p-value: 0.0
#
# Kendall:
# 	corr: 0.112
# 	p-value: 0.0

# %%
ds, rc = 'gow', 'lore'
acc10, acc50, acc100, preds = get_result(ds, rc)
plt_chart(preds, acc50, 'Dataset: Gowalla; Recommender: LORE', 'Predictability', 'Accuracy@50')
get_corr(preds, acc50)
# Out:
# Pearson:
# 	corr: 0.163
# 	p-value: 0.163
#
# Spearman:
# 	corr: 0.177
# 	p-value: 0.0
#
# Kendall:
# 	corr: 0.132
# 	p-value: 0.0

# %%
ds, rc = 'gow', 'lore'
acc10, acc50, acc100, preds = get_result(ds, rc)
plt_chart(preds, acc100, 'Dataset: Gowalla; Recommender: LORE', 'Predictability', 'Accuracy@100')
get_corr(preds, acc100)
# Out:
# Pearson:
# 	corr: 0.172
# 	p-value: 0.172
#
# Spearman:
# 	corr: 0.191
# 	p-value: 0.0
#
# Kendall:
# 	corr: 0.142
# 	p-value: 0.0

# %%
ds, rc = 'yelp', 'usg'
acc10, acc50, acc100, preds = get_result(ds, rc)
plt_chart(preds, acc10, 'Dataset: Yelp; Recommender: USG', 'Predictability', 'Accuracy@10')
get_corr(preds, acc10)
# Out:
# Pearson:
# 	corr: -0.019
# 	p-value: -0.019
#
# Spearman:
# 	corr: 0.036
# 	p-value: 0.0
#
# Kendall:
# 	corr: 0.031
# 	p-value: 0.0

# %%
ds, rc = 'yelp', 'usg'
acc10, acc50, acc100, preds = get_result(ds, rc)
plt_chart(preds, acc50, 'Dataset: Yelp; Recommender: USG', 'Predictability', 'Accuracy@50')
get_corr(preds, acc50)
# Out:
# Pearson:
# 	corr: -0.025
# 	p-value: -0.025
#
# Spearman:
# 	corr: 0.016
# 	p-value: 0.006
#
# Kendall:
# 	corr: 0.013
# 	p-value: 0.005

# %%
ds, rc = 'yelp', 'usg'
acc10, acc50, acc100, preds = get_result(ds, rc)
plt_chart(preds, acc100, 'Dataset: Yelp; Recommender: USG', 'Predictability', 'Accuracy@100')
get_corr(preds, acc100)
# Out:
# Pearson:
# 	corr: -0.025
# 	p-value: -0.025
#
# Spearman:
# 	corr: 0.0
# 	p-value: 0.957
#
# Kendall:
# 	corr: 0.001
# 	p-value: 0.9

# %%
ds, rc = 'gow', 'usg'
acc10, acc50, acc100, preds = get_result(ds, rc)
plt_chart(preds, acc10, 'Dataset: Gowalla; Recommender: USG', 'Predictability', 'Accuracy@10')
get_corr(preds, acc10)
# Out:
# Pearson:
# 	corr: 0.022
# 	p-value: 0.022
#
# Spearman:
# 	corr: 0.057
# 	p-value: 0.0
#
# Kendall:
# 	corr: 0.043
# 	p-value: 0.0

# %%
ds, rc = 'gow', 'usg'
acc10, acc50, acc100, preds = get_result(ds, rc)
plt_chart(preds, acc50, 'Dataset: Gowalla; Recommender: USG', 'Predictability', 'Accuracy@50')
get_corr(preds, acc50)
# Out:
# Pearson:
# 	corr: 0.069
# 	p-value: 0.069
#
# Spearman:
# 	corr: 0.084
# 	p-value: 0.0
#
# Kendall:
# 	corr: 0.06
# 	p-value: 0.0

# %%
ds, rc = 'gow', 'usg'
acc10, acc50, acc100, preds = get_result(ds, rc)
plt_chart(preds, acc100, 'Dataset: Gowalla; Recommender: USG', 'Predictability', 'Accuracy@100')
get_corr(preds, acc100)
# Out:
# Pearson:
# 	corr: 0.08
# 	p-value: 0.08
#
# Spearman:
# 	corr: 0.087
# 	p-value: 0.0
#
# Kendall:
# 	corr: 0.061
# 	p-value: 0.0
